# %%
import pandas as pd
import numpy as np

# %%
data = [10, 20, 30, 40]
data
# Out:
# [10, 20, 30, 40]

# %%
series = pd.Series(data)
series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
custom_series = pd.Series(data , index = ['a','b','c','d'])
custom_series
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data2 = {
    "a1": 10,
    "b1": 20,
    "c1": 30
}

# %%
series2 = pd.Series(data2)
series2
# Out:
# a1    10
# b1    20
# c1    30
# dtype: int64

# %%
arr = np.arange(1,5)
arr
# Out:
# array([1, 2, 3, 4])

# %%
series3 = pd.Series(arr)
series3
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
index = ['w','x','y','z']

# %%
series4 = pd.Series(arr,index = index )
series4
# Out:
# w    1
# x    2
# y    3
# z    4
# dtype: int64
